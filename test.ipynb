# %%
from bs4 import BeautifulSoup 
import urllib

# %%
html = urllib.request.urlopen("https://www.nikkei.com/markets/ranking/page/?bd=betahigh&Gcode=41&hm=1")
soup = BeautifulSoup(html,"lxml")

# %%
a=soup.find_all("td")
print (a)
# Out:
# [<td>
# <div class="m-stockInfo_meigarayutaiBtn">
# <form action="#" method="post" onclick="_nk.click(this,event,[['JSID_actMyBalloon',{'JSID_dataMyBalloonId':'#JSID_htmlBalloonMeigara'}]]);return false">
# <a class="a-registrable-btn" href="javascript:void(0)">追加</a>
# </form>
# <div class="cmn-hide" id="JSID_htmlBalloonMeigara">
# <div class="cmnc-balloonTitle cmnc-balloonTitle-myNews">
# <h6 class="" style="color:#333333;">銘柄フォルダに追加</h6>
# </div>
# <p>
#
#                         有料会員・登録会員の方がご利用になれます。<br/> 銘柄フォルダ追加にはログインが必要です。
#                     </p>
# <div class="cmnc-balloonAction">
# <a class="cmn-button cmn-button-followLogin cmn-button-half" href="https://www.nikkei.com/etc/accounts/login?dps=1&amp;url=https%3A%2F%2Fwww.nikkei.com%2Fmarkets%2Franking%2Fpage%2F%3FGcode%3D41%26bd%3Dbetahigh%26hm%3D1"><span class="cmnc-label">ログイン</span></a></div>
# </div>
# </div>
# <script type="text/javascript">
#     _nk.setMeigaraFolder();
#     _nk.setDoublePopup();
# </script>
# ...

# %%
for a in soup.find_all('a'):
    p = a.get('href')
   
    print(p)
# Out:
# /
# javascript:void(0)
# http://asia.nikkei.com/?n_cid=NARAN101
# http://www.ft.com/
# http://cn.nikkei.com/
# javascript:void(0)
# https://regist.nikkei.com/support/
# http://chatfaq.nikkei.com/
# http://www.nikkei.com/help/
# https://id.nikkei.com/lounge/
# /r123/?n_cid=DSPRM1352
# javascript:void(0)
# /r123/?n_cid=DSPRM036
# /
# /news/category/
# /access/
# /theme/list/
# /news/jinji/
# /news/okuyami/
# /pressrelease/
# https://vdata.nikkei.com/
# /photo/
# http://www.nikkei.com/video/?n_cid=DTOPV001
# /opinion/editorial/
# https://vdata.nikkei.com/economicdashboard/macro/
# /economy/
# /economy/economic/
# /economy/politics/
# /economy/monetary/
# /economy/column/
# /theme/?dw=18051501
# /theme/?dw=18060400
# /theme/?dw=17101601
# /theme/?dw=17090301
# /theme/?dw=18032900
# /theme/?dw=17101910
# /theme/?dw=17101602
# /theme/?dw=17090313
# /theme/?dw=17092101
# /theme/?dw=17090315
# /theme/?dw=17092100
# /theme/?dw=17090318
# /business/
# /business/startups/
# /business/house/
# ...

# %%
beta = ""

    
for tag in span:
    try:
        string_ = tag.get("class").pop(0)
        if string_ in "colorRed":
            beta = tag.string
            break
    except:
        # パス→何も処理を行わない
        pass

# 摘出した日経平均株価を出力します。
print (beta)
# Out:
#   File "<ipython-input-30-0d002731c084>", line 2
#     span = a.get('a')
#     ^
# IndentationError: unexpected indent
